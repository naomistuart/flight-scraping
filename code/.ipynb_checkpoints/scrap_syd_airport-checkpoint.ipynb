# %%
## IDEAS
# allow user to choose to display arrvials, or departures, domestic or international
# display some graphics
# image path https://www.sydneyairport.com.au/flights/logo/VA
# combine all (arrivals, departures, international, domestic) into one data frame
# add two columns - flight_type, terminal_type

# %%
from datetime import datetime
from selenium import webdriver
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
driver = webdriver.Chrome()

# %%
# Define query strings for url
today = datetime.today().strftime('%Y-%m-%d')
flight_types  = ["arrival", "departure"]
terminal_types = ["international", "domestic"]

# Initialise empty lists
journies = []
types = []
terminals = []
stopovers = []
airlines = []
airline_logos = []
flight_numbers = []
other_flight_numbers = []
statuses = []
scheduled_times = []
estimated_times = []

# Loop through each combination of (domestic/international) x (arrival/departure )
for flight_type in flight_types:
    for terminal_type in terminal_types:
        url = "https://www.sydneyairport.com.au/flights/?query=&flightType=" + flight_type + "&terminalType=" + terminal_type + "&date=" + today + "&sortColumn=scheduled_time&ascending=true&showAll=true"
        driver.get(url)
        
        html_soup = BeautifulSoup(driver.page_source, "html.parser")
        flight_containers = html_soup.find_all("div", attrs={"class": "flight-card"})[2:]
        
        # Loop through all containers (one for each flight) to extract and store info
        for container in flight_containers:
            # Arrival / departure
            types.append(flight_type)
            
            # International / domestic
            terminals.append(terminal_type)
            
            # Origin / Destinations
            journies.append(container.find("div", attrs={"class": "destination-name"}).text)

            # Stopovers (if any)
            if container.find("div", attrs={"class": "city-via"}) is not None:
                stopovers.append(container.find("div", attrs={"class": "city-via"}).text)
            else:
                stopovers.append(None)

            # Airlines
            airlines.append(container.find("span", attrs={"class": "with-image"}).text)

            # Airline logos
            airline_logos.append(container.img['src'])

            # Flight numbers
            flight_numbers.append(container.find("div", attrs={"class": "heading-medium"}).text)

            # Alternative flight numbers (if any)
            if container.find("div", attrs={"class": "body-xsmall"}) is not None:
                other_flight_numbers.append(container.find("div", attrs={"class": "body-xsmall"}).text)
            else:
                other_flight_numbers.append(None)

            # Statuses
            statuses.append(container.find("div", attrs={"class": "status"}).text)

            # Scheduled times
            scheduled_times.append(container.find("div", attrs={"class": "large-scheduled-time"}).text)

            # Estimated times
            estimated_times.append(container.find("div", attrs={"class": "estimated-time"}).text)
    
    
# Create dataframe from lists
flights = pd.DataFrame({'journey': journies,
                        'type': types,
                        'terminal': terminals,
                        'stopover': stopovers,
                        'airline': airlines,
                        'airline_logo': airline_logos,
                        'flight_number': flight_numbers,
                        'other_flight_number': other_flight_numbers,
                        'status': statuses,
                        'scheduled_time': scheduled_times,
                        'estimated_time': estimated_times})
# Reorder columns
flights = flights[['type', 'terminal', 'journey', 'stopover', 'airline', 'airline_logo', 'flight_number', 'other_flight_number', 'status', 'scheduled_time', 'estimated_time']]

flights
# Out:
#           type       terminal        journey         stopover  \
# 0      arrival  international         London    Via Singapore
# 1      arrival  international         London    Via Singapore
# 2      arrival  international      Singapore             None
# 3      arrival  international          Dubai             None
# 4      arrival  international        Jakarta             None
# 5      arrival  international  San Francisco             None
# 6      arrival  international       Denpasar             None
# 7      arrival  international          Tokyo             None
# 8      arrival  international          Delhi             None
# 9      arrival  international         Manila             None
# 10     arrival  international          Seoul             None
# 11     arrival  international      Hong Kong             None
# 12     arrival  international       Denpasar             None
# 13     arrival  international       Denpasar             None
# 14     arrival  international        Bangkok             None
# 15     arrival  international         Dallas             None
# 16     arrival  international       New York  Via Los Angeles
# 17     arrival  international           Doha             None
# 18     arrival  international      Abu Dhabi             None
# 19     arrival  international    Los Angeles             None
# 20     arrival  international  San Francisco             None
# 21     arrival  international      Hong Kong             None
# 22     arrival  international      Singapore             None
# 23     arrival  international        Houston             None
# 24     arrival  international          Osaka             None
# 25     arrival  international      Hong Kong             None
# 26     arrival  international        Bangkok             None
# 27     arrival  international       Denpasar             None
# 28     arrival  international       Denpasar             None
# 29     arrival  international    Los Angeles             None
# ..         ...            ...            ...              ...
# 841  departure       domestic         Hobart             None
# 842  departure       domestic       Brisbane             None
# 843  departure       domestic       Brisbane             None
# 844  departure       domestic      Melbourne             None
# 845  departure       domestic       Canberra             None
# 846  departure       domestic       Canberra             None
# 847  departure       domestic          Perth             None
# 848  departure       domestic          Perth             None
# 849  departure       domestic       Brisbane             None
# 850  departure       domestic      Melbourne             None
# 851  departure       domestic      Melbourne             None
# 852  departure       domestic     Gold Coast             None
# 853  departure       domestic         Darwin             None
# 854  departure       domestic       Canberra             None
# 855  departure       domestic       Adelaide             None
# 856  departure       domestic       Adelaide             None
# 857  departure       domestic      Melbourne             None
# 858  departure       domestic          Perth             None
# 859  departure       domestic       Canberra             None
# 860  departure       domestic      Melbourne             None
# 861  departure       domestic      Melbourne             None
# 862  departure       domestic       Brisbane             None
# 863  departure       domestic         Darwin             None
# 864  departure       domestic       Brisbane             None
# 865  departure       domestic      Melbourne             None
# 866  departure       domestic       Brisbane             None
# 867  departure       domestic       Brisbane             None
# 868  departure       domestic         Avalon             None
# 869  departure       domestic      Melbourne             None
# 870  departure       domestic      Melbourne             None
#
#                     airline      airline_logo flight_number  \
# 0                    Qantas  /flights/logo/QF           QF2
# 1          British Airways   /flights/logo/BA          BA15
# 2       Singapore Airlines   /flights/logo/SQ         SQ221
# 3                 Emirates   /flights/logo/EK         EK412
# 4                    Qantas  /flights/logo/QF          QF42
# 5                    Qantas  /flights/logo/QF          QF74
# 6          Virgin Australia  /flights/logo/VA          VA36
# 7            Japan Airlines  /flights/logo/JL         JL771
# 8                 Air India  /flights/logo/AI         AI302
# 9                    Qantas  /flights/logo/QF          QF20
# 10               Korean Air  /flights/logo/KE         KE121
# 11   Cathay Pacific Airways  /flights/logo/CX         CX111
# 12                  Jetstar  /flights/logo/JQ          JQ38
# 13                   Qantas  /flights/logo/QF          QF44
# 14                   Qantas  /flights/logo/QF          QF24
# 15                   Qantas  /flights/logo/QF           QF8
# 16                   Qantas  /flights/logo/QF          QF12
# 17            Qatar Airways  /flights/logo/QR         QR906
# 18          Etihad Airways   /flights/logo/EY         EY450
# 19          Delta Air Lines  /flights/logo/DL          DL41
# 20          United Airlines  /flights/logo/UA         UA863
# 21                   Qantas  /flights/logo/QF         QF128
# 22                   Qantas  /flights/logo/QF          QF82
# 23          United Airlines  /flights/logo/UA         UA101
# 24                   Qantas  /flights/logo/QF          QF34
# 25         Virgin Australia  /flights/logo/VA          VA82
# 26             Thai Airways  /flights/logo/TG         TG475
# 27        Garuda Indonesia   /flights/logo/GA         GA714
# 28         Virgin Australia  /flights/logo/VA          VA34
# 29        American Airlines  /flights/logo/AA          AA73
# ..                      ...               ...           ...
# 841                  Qantas  /flights/logo/QF        QF1585
# 842                 Jetstar  /flights/logo/JQ         JQ820
# 843        Virgin Australia  /flights/logo/VA         VA985
# 844                  Qantas  /flights/logo/QF         QF467
# 845        Virgin Australia  /flights/logo/VA         VA670
# 846                  Qantas  /flights/logo/QF        QF1495
# 847                  Qantas  /flights/logo/QF         QF583
# 848                 Jetstar  /flights/logo/JQ         JQ988
# 849        Virgin Australia  /flights/logo/VA         VA989
# 850                  Qantas  /flights/logo/QF         QF487
# 851        Virgin Australia  /flights/logo/VA         VA888
# 852        Virgin Australia  /flights/logo/VA         VA545
# 853                 Jetstar  /flights/logo/JQ         JQ672
# 854                  Qantas  /flights/logo/QF        QF1499
# 855        Virgin Australia  /flights/logo/VA         VA444
# 856                  Qantas  /flights/logo/QF         QF785
# 857                  Qantas  /flights/logo/QF         QF491
# 858                Tigerair  /flights/logo/TT         TT763
# 859        Virgin Australia  /flights/logo/VA         VA672
# 860                Tigerair  /flights/logo/TT         TT279
# 861                 Jetstar  /flights/logo/JQ         JQ527
# 862                 Jetstar  /flights/logo/JQ         JQ822
# 863                  Qantas  /flights/logo/QF         QF846
# 864                  Qantas  /flights/logo/QF         QF554
# 865        Virgin Australia  /flights/logo/VA         VA894
# 866        Virgin Australia  /flights/logo/VA         VA997
# 867                  Qantas  /flights/logo/QF         QF556
# 868                 Jetstar  /flights/logo/JQ         JQ611
# 869                 Jetstar  /flights/logo/JQ         JQ529
# 870                  Qantas  /flights/logo/QF         QF497
#
#                                    other_flight_number     status  \
# 0                                               EK5002    Arrived
# 1                                       AY5915, IB4745    Arrived
# 2    A31213, AF7232, ET1317, LH9780, LX4172, TK9312...    Arrived
# 3                                               QF8412    Arrived
# 4                                                 None    Arrived
# 5                                               AA7396    Arrived
# 6                                                 None    Arrived
# 7                                               LA7467    Arrived
# 8                                                 None    Arrived
# 9                                                 None    Arrived
# 10                                      AF7876, KL9160    Arrived
# 11      KC1712, BA4133, OM5601, LH7001, LX9501, AY5841    Arrived
# 12                                               QF270    Arrived
# 13                                                None    Arrived
# 14                              AY5001, EK5024, PG4531    Arrived
# 15                                              AA7375    Arrived
# 16                                              AA7364    Arrived
# 17                                                None    Arrived
# 18   AF3824, AZ3926, EI8050, KL3936, KM2121, ME6634...    Arrived
# 19                                              VA6551    Arrived
# 20                                      NZ9863, LH9327    Arrived
# 21                                      9W4028, AY5005    Arrived
# 22      9W4082, EK5062, MU8470, AY5011, UL3372, PG4535    Arrived
# 23                                                None    Arrived
# 24                                                None    Arrived
# 25                                                None    Arrived
# 26                      TK8020, LH9744, OS8639, LY8401    Arrived
# 27                                                None    Arrived
# 28                                                None    Arrived
# 29                                                None    Arrived
# ..                                                 ...        ...
# 841                                               None   Departed
# 842                                               None   Departed
# 843                                               None  Cancelled
# 844                                               None   Departed
# 845                                             EY6706   Departed
# 846                                               None   Departed
# 847                                               None   Departed
# 848                                               None   Departed
# 849                                             EY6812   Departed
# 850                                               None   Departed
# 851                                             EY6962   Departed
# 852                                             EY6921   Departed
# 853                                               None   Departed
# 854                                               None   Departed
# 855                                               None   Departed
# 856                                               None   Departed
# 857                                               None   Departed
# 858                                               None   Departed
# 859                                     EY6829, SQ6747   Departed
# 860                                               None   Departed
# 861                                               None   Departed
# 862                                               None   Departed
# 863                                               None   Departed
# 864                                               None   Departed
# 865                                             EY6878   Departed
# 866                                             EY6817   Departed
# 867                                               None   Departed
# 868                                               None   Departed
# 869                                               None    On Time
# 870                                               None    On Time
#
#     scheduled_time estimated_time
# 0            05:10          05:01
# 1            05:10          05:05
# 2            05:55          05:38
# 3            06:05          06:10
# 4            06:05          06:04
# 5            06:05          06:02
# 6            06:10          06:01
# 7            06:10          06:24
# 8            06:10          06:40
# 9            06:10          06:10
# 10           06:15          06:37
# 11           06:15          06:12
# 12           06:15          06:13
# 13           06:25          06:26
# 14           06:25          06:15
# 15           06:25          06:20
# 16           06:30          06:22
# 17           06:30          06:49
# 18           06:30          06:28
# 19           06:35          06:34
# 20           06:55          06:56
# 21           06:55          07:30
# 22           07:00          06:31
# 23           07:00          06:53
# 24           07:10          07:10
# 25           07:10          06:59
# 26           07:20          07:06
# 27           07:25          06:56
# 28           07:25          07:01
# 29           07:25          07:03
# ..             ...            ...
# 841          19:20              -
# 842          19:25          19:30
# 843          19:30              -
# 844          19:30              -
# 845          19:35          19:35
# 846          19:35              -
# 847          19:50          20:00
# 848          19:55              -
# 849          20:00          20:00
# 850          20:00              -
# 851          20:00          20:02
# 852          20:10          20:19
# 853          20:10          20:25
# 854          20:15          20:55
# 855          20:15          20:38
# 856          20:20              -
# 857          20:30              -
# 858          20:30              -
# 859          20:35          20:35
# 860          20:35              -
# 861          20:40              -
# 862          20:40          21:20
# 863          20:45              -
# 864          21:00              -
# 865          21:00          21:00
# 866          21:00          21:00
# 867          21:45              -
# 868          21:55              -
# 869          22:00          22:45
# 870          22:05              -
#
# [871 rows x 11 columns]

# %%
flights[flights['status']=='Cancelled']
# Out:
#           type       terminal     journey stopover           airline  \
# 118    arrival       domestic   Melbourne     None           Jetstar
# 165    arrival       domestic       Cooma     None               Rex
# 177    arrival       domestic   Melbourne     None            Qantas
# 181    arrival       domestic    Adelaide     None           Jetstar
# 244    arrival       domestic  Gold Coast     None           Jetstar
# 288    arrival       domestic   Melbourne     None           Jetstar
# 302    arrival       domestic   Melbourne     None           Jetstar
# 343    arrival       domestic   Melbourne     None  Virgin Australia
# 358    arrival       domestic    Brisbane     None            Qantas
# 373    arrival       domestic   Melbourne     None  Virgin Australia
# 428  departure  international        Nadi     None      Fiji Airways
# 548  departure       domestic    Adelaide     None           Jetstar
# 564  departure       domestic       Cooma     None               Rex
# 638  departure       domestic  Gold Coast     None           Jetstar
# 659  departure       domestic      Mudgee     None       Fly Pelican
# 775  departure       domestic   Melbourne     None           Jetstar
# 798  departure       domestic   Melbourne     None           Jetstar
# 813  departure       domestic   Melbourne     None            Qantas
# 819  departure       domestic   Newcastle     None               Rex
# 843  departure       domestic    Brisbane     None  Virgin Australia
#
#          airline_logo flight_number other_flight_number     status  \
# 118  /flights/logo/JQ         JQ500                None  Cancelled
# 165  /flights/logo/ZL         ZL722                None  Cancelled
# 177  /flights/logo/QF         QF422                None  Cancelled
# 181  /flights/logo/JQ         JQ763                None  Cancelled
# 244  /flights/logo/JQ         JQ411                None  Cancelled
# 288  /flights/logo/JQ         JQ514                None  Cancelled
# 302  /flights/logo/JQ         JQ518                None  Cancelled
# 343  /flights/logo/VA         VA869              EY6707  Cancelled
# 358  /flights/logo/QF         QF547                None  Cancelled
# 373  /flights/logo/VA         VA879              EY6949  Cancelled
# 428  /flights/logo/FJ         FJ914               QF345  Cancelled
# 548  /flights/logo/JQ         JQ762                None  Cancelled
# 564  /flights/logo/ZL         ZL721                None  Cancelled
# 638  /flights/logo/JQ         JQ408                None  Cancelled
# 659  /flights/logo/FP         FP247                None  Cancelled
# 775  /flights/logo/JQ         JQ517                None  Cancelled
# 798  /flights/logo/JQ         JQ523                None  Cancelled
# 813  /flights/logo/QF         QF479                None  Cancelled
# 819  /flights/logo/ZL         ZL382                None  Cancelled
# 843  /flights/logo/VA         VA985                None  Cancelled
#
#     scheduled_time estimated_time
# 118          07:25              -
# 165          10:40              -
# 177          11:25              -
# 181          11:30              -
# 244          14:50              -
# 288          16:45              -
# 302          17:30              -
# 343          18:40              -
# 358          19:10              -
# 373          19:55              -
# 428          06:15              -
# 548          06:55              -
# 564          08:00              -
# 638          11:30              -
# 659          12:20              -
# 775          17:25              -
# 798          18:15              -
# 813          18:45          19:20
# 819          18:50              -
# 843          19:30              -
