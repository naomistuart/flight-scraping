# %%
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
chrome_options = Options()  
chrome_options.add_argument("--headless")
driver = webdriver.Chrome(options=chrome_options)

# %%
# Define query strings for url
today = datetime.today().strftime('%Y-%m-%d')
flight_types  = ["arrival", "departure"]
terminal_types = ["international", "domestic"]

# Initialise empty lists
airlines = []
airline_logos = []

# Loop through each combination of (domestic/international) x (arrival/departure)
for flight_type in flight_types:
    for terminal_type in terminal_types:
        url = "https://www.sydneyairport.com.au/flights/?query=&flightType=" + flight_type + "&terminalType=" + terminal_type + "&date=" + today + "&sortColumn=scheduled_time&ascending=true&showAll=true"
        driver.get(url)
        
        html_soup = BeautifulSoup(driver.page_source, "html.parser")
        flight_containers = html_soup.find_all("div", attrs={"class": "flight-card"})[2:]
        
        # Loop through all containers (one for each flight) to extract and store info
        for container in flight_containers:
            # Airlines
            airlines.append(container.find("span", attrs={"class": "with-image"}).text)

            # Airline logos
            airline_logos.append("https://www.sydneyairport.com.au" + container.img['src'])
    
    
# Create dataframe from lists
airlines= pd.DataFrame({'airline': airlines,
                        'airline_logo': airline_logos})
# Reorder columns
airlines = airlines[['airline', 'airline_logo']]

airlines
# Out:
#                       airline  \
# 0                      Qantas
# 1            British Airways
# 2         Singapore Airlines
# 3                      Qantas
# 4                      Qantas
# 5                   Emirates
# 6                   Air India
# 7            Virgin Australia
# 8              Japan Airlines
# 9                      Qantas
# 10                    Jetstar
# 11                 Korean Air
# 12     Cathay Pacific Airways
# 13                     Qantas
# 14   China Southern Airlines
# 15                     Qantas
# 16                     Qantas
# 17              Qatar Airways
# 18                     Qantas
# 19            Etihad Airways
# 20            Delta Air Lines
# 21            United Airlines
# 22                     Qantas
# 23            United Airlines
# 24            Hainan Airlines
# 25                     Qantas
# 26           Virgin Australia
# 27               Thai Airways
# 28          American Airlines
# 29          Garuda Indonesia
# ..                        ...
# 676                   Jetstar
# 677                   Jetstar
# 678          Virgin Australia
# 679                       Rex
# 680                    Qantas
# 681                   Jetstar
# 682                    Qantas
# 683                   Jetstar
# 684                  Tigerair
# 685                       Rex
# 686                    Qantas
# 687          Virgin Australia
# 688                    Qantas
# 689                       Rex
# 690                    Qantas
# 691          Virgin Australia
# 692                   Jetstar
# 693          Virgin Australia
# 694                   Jetstar
# 695                    Qantas
# 696                    Qantas
# 697                    Qantas
# 698                   Jetstar
# 699          Virgin Australia
# 700                  Tigerair
# 701          Virgin Australia
# 702                   Jetstar
# 703                   Jetstar
# 704                   Jetstar
# 705                    Qantas
#
#                                          airline_logo
# 0    https://www.sydneyairport.com.au/flights/logo/QF
# 1    https://www.sydneyairport.com.au/flights/logo/BA
# 2    https://www.sydneyairport.com.au/flights/logo/SQ
# 3    https://www.sydneyairport.com.au/flights/logo/QF
# 4    https://www.sydneyairport.com.au/flights/logo/QF
# 5    https://www.sydneyairport.com.au/flights/logo/EK
# 6    https://www.sydneyairport.com.au/flights/logo/AI
# 7    https://www.sydneyairport.com.au/flights/logo/VA
# 8    https://www.sydneyairport.com.au/flights/logo/JL
# 9    https://www.sydneyairport.com.au/flights/logo/QF
# 10   https://www.sydneyairport.com.au/flights/logo/JQ
# 11   https://www.sydneyairport.com.au/flights/logo/KE
# 12   https://www.sydneyairport.com.au/flights/logo/CX
# 13   https://www.sydneyairport.com.au/flights/logo/QF
# 14   https://www.sydneyairport.com.au/flights/logo/CZ
# 15   https://www.sydneyairport.com.au/flights/logo/QF
# 16   https://www.sydneyairport.com.au/flights/logo/QF
# 17   https://www.sydneyairport.com.au/flights/logo/QR
# 18   https://www.sydneyairport.com.au/flights/logo/QF
# 19   https://www.sydneyairport.com.au/flights/logo/EY
# 20   https://www.sydneyairport.com.au/flights/logo/DL
# 21   https://www.sydneyairport.com.au/flights/logo/UA
# 22   https://www.sydneyairport.com.au/flights/logo/QF
# 23   https://www.sydneyairport.com.au/flights/logo/UA
# 24   https://www.sydneyairport.com.au/flights/logo/HU
# 25   https://www.sydneyairport.com.au/flights/logo/QF
# 26   https://www.sydneyairport.com.au/flights/logo/VA
# 27   https://www.sydneyairport.com.au/flights/logo/TG
# 28   https://www.sydneyairport.com.au/flights/logo/AA
# 29   https://www.sydneyairport.com.au/flights/logo/GA
# ..                                                ...
# 676  https://www.sydneyairport.com.au/flights/logo/JQ
# 677  https://www.sydneyairport.com.au/flights/logo/JQ
# 678  https://www.sydneyairport.com.au/flights/logo/VA
# 679  https://www.sydneyairport.com.au/flights/logo/ZL
# 680  https://www.sydneyairport.com.au/flights/logo/QF
# 681  https://www.sydneyairport.com.au/flights/logo/JQ
# 682  https://www.sydneyairport.com.au/flights/logo/QF
# 683  https://www.sydneyairport.com.au/flights/logo/JQ
# 684  https://www.sydneyairport.com.au/flights/logo/TT
# 685  https://www.sydneyairport.com.au/flights/logo/ZL
# 686  https://www.sydneyairport.com.au/flights/logo/QF
# 687  https://www.sydneyairport.com.au/flights/logo/VA
# 688  https://www.sydneyairport.com.au/flights/logo/QF
# 689  https://www.sydneyairport.com.au/flights/logo/ZL
# 690  https://www.sydneyairport.com.au/flights/logo/QF
# 691  https://www.sydneyairport.com.au/flights/logo/VA
# 692  https://www.sydneyairport.com.au/flights/logo/JQ
# 693  https://www.sydneyairport.com.au/flights/logo/VA
# 694  https://www.sydneyairport.com.au/flights/logo/JQ
# 695  https://www.sydneyairport.com.au/flights/logo/QF
# 696  https://www.sydneyairport.com.au/flights/logo/QF
# 697  https://www.sydneyairport.com.au/flights/logo/QF
# 698  https://www.sydneyairport.com.au/flights/logo/JQ
# 699  https://www.sydneyairport.com.au/flights/logo/VA
# 700  https://www.sydneyairport.com.au/flights/logo/TT
# 701  https://www.sydneyairport.com.au/flights/logo/VA
# 702  https://www.sydneyairport.com.au/flights/logo/JQ
# 703  https://www.sydneyairport.com.au/flights/logo/JQ
# 704  https://www.sydneyairport.com.au/flights/logo/JQ
# 705  https://www.sydneyairport.com.au/flights/logo/QF
#
# [706 rows x 2 columns]
