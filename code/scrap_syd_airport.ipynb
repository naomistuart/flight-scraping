# %%
## IDEAS
# allow user to choose to display arrvials, or departures, domestic or international
# display some graphics
# image path https://www.sydneyairport.com.au/flights/logo/VA
# combine all (arrivals, departures, international, domestic) into one data frame
# add two columns - flight_type, terminal_type

# %%
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
chrome_options = Options()  
chrome_options.add_argument("--headless")
driver = webdriver.Chrome(options=chrome_options)

# %%
# Define query strings for url
today = datetime.today().strftime('%Y-%m-%d')
flight_types  = ["arrival", "departure"]
terminal_types = ["international", "domestic"]

# Initialise empty lists
journies = []
types = []
terminals = []
stopovers = []
airlines = []
airline_logos = []
flight_numbers = []
other_flight_numbers = []
statuses = []
scheduled_times = []
estimated_times = []

# Loop through each combination of (domestic/international) x (arrival/departure)
for flight_type in flight_types:
    for terminal_type in terminal_types:
        url = "https://www.sydneyairport.com.au/flights/?query=&flightType=" + flight_type + "&terminalType=" + terminal_type + "&date=" + today + "&sortColumn=scheduled_time&ascending=true&showAll=true"
        driver.get(url)
        
        html_soup = BeautifulSoup(driver.page_source, "html.parser")
        flight_containers = html_soup.find_all("div", attrs={"class": "flight-card"})[2:]
        
        # Loop through all containers (one for each flight) to extract and store info
        for container in flight_containers:
            # Arrival / departure
            types.append(flight_type)
            
            # International / domestic
            terminals.append(terminal_type)
            
            # Origin / Destinations
            journies.append(container.find("div", attrs={"class": "destination-name"}).text)

            # Stopovers (if any)
            if container.find("div", attrs={"class": "city-via"}) is not None:
                stopovers.append(container.find("div", attrs={"class": "city-via"}).text)
            else:
                stopovers.append(None)

            # Airlines
            airlines.append(container.find("span", attrs={"class": "with-image"}).text)

            # Airline logos
            #airline_logos.append("https://www.sydneyairport.com.au" + container.img['src'])
            logo_url = "https://www.sydneyairport.com.au" + container.img['src']
            driver.get(logo_url)
            logo_soup = BeautifulSoup(driver.page_source, "html.parser")
            airline_logos.append(logo_soup.img['src'])

            # Flight numbers
            flight_numbers.append(container.find("div", attrs={"class": "heading-medium"}).text)

            # Alternative flight numbers (if any)
            if container.find("div", attrs={"class": "body-xsmall"}) is not None:
                other_flight_numbers.append(container.find("div", attrs={"class": "body-xsmall"}).text)
            else:
                other_flight_numbers.append(None)

            # Statuses
            statuses.append(container.find("div", attrs={"class": "status"}).text)

            # Scheduled times
            scheduled_times.append(container.find("div", attrs={"class": "large-scheduled-time"}).text)

            # Estimated times
            estimated_times.append(container.find("div", attrs={"class": "estimated-time"}).text)
    
    
# Create dataframe from lists
flights = pd.DataFrame({'journey': journies,
                        'type': types,
                        'terminal': terminals,
                        'stopover': stopovers,
                        'airline': airlines,
                        'airline_logo': airline_logos,
                        'flight_number': flight_numbers,
                        'other_flight_number': other_flight_numbers,
                        'status': statuses,
                        'scheduled_time': scheduled_times,
                        'estimated_time': estimated_times})
# Reorder columns
flights = flights[['type', 'terminal', 'journey', 'stopover', 'airline', 'airline_logo', 'flight_number', 'other_flight_number', 'status', 'scheduled_time', 'estimated_time']]

flights
# Out:
#           type       terminal         journey         stopover  \
# 0    arrival    international  London          Via Singapore
# 1    arrival    international  London          Via Singapore
# 2    arrival    international  Singapore       None
# 434  Qantas
# 435  Virgin Australia
# 436  Jetstar
# 437  Virgin Australia
# 438  Jetstar
# 439  Qantas
# 440  Qantas
# 441  Qantas
# 442  Jetstar
# 443  Virgin Australia
# 444  Tigerair
# 445  Virgin Australia
# 446  Jetstar
# 447  Jetstar
# 448  Jetstar
# 449  Qantas
#
#                                          airline_logo flight_number  \
# 0    https://www.sydneyairport.com.au/flights/logo/QF  QF2
# 1    https://www.sydneyairport.com.au/flights/logo/BA  BA15
# 2    https://www.sydneyairport.com.au/flights/logo/SQ  SQ221
# 3    https://www.sydneyairport.com.au/flights/logo/QF  QF74
# 4    https://www.sydneyairport.com.au/flights/logo/QF  QF42
# 5    https://www.sydneyairport.com.au/flights/logo/EK  EK412
# 6    https://www.sydneyairport.com.au/flights/logo/AI  AI302
# 7    https://www.sydneyairport.com.au/flights/logo/VA  VA36
# 8    https://www.sydneyairport.com.au/flights/logo/JL  JL771
# 9    https://www.sydneyairport.com.au/flights/logo/QF  QF20
# 10   https://www.sydneyairport.com.au/flights/logo/JQ  JQ38
# 11   https://www.sydneyairport.com.au/flights/logo/KE  KE121
# 12   https://www.sydneyairport.com.au/flights/logo/CX  CX111
# 13   https://www.sydneyairport.com.au/flights/logo/QF  QF8
# 14   https://www.sydneyairport.com.au/flights/logo/CZ  CZ3071
# 15   https://www.sydneyairport.com.au/flights/logo/QF  QF44
# 16   https://www.sydneyairport.com.au/flights/logo/QF  QF24
# 17   https://www.sydneyairport.com.au/flights/logo/QR  QR906
# 18   https://www.sydneyairport.com.au/flights/logo/QF  QF12
# 19   https://www.sydneyairport.com.au/flights/logo/EY  EY450
# 20   https://www.sydneyairport.com.au/flights/logo/DL  DL41
# 21   https://www.sydneyairport.com.au/flights/logo/UA  UA863
# 22   https://www.sydneyairport.com.au/flights/logo/QF  QF128
# 23   https://www.sydneyairport.com.au/flights/logo/UA  UA839
# 24   https://www.sydneyairport.com.au/flights/logo/HU  HU7997
# 25   https://www.sydneyairport.com.au/flights/logo/QF  QF82
# 26   https://www.sydneyairport.com.au/flights/logo/VA  VA82
# 27   https://www.sydneyairport.com.au/flights/logo/TG  TG475
# 28   https://www.sydneyairport.com.au/flights/logo/AA  AA73
# 29   https://www.sydneyairport.com.au/flights/logo/GA  GA714
# ..                                                ...    ...
# 420  https://www.sydneyairport.com.au/flights/logo/JQ  JQ788
# 421  https://www.sydneyairport.com.au/flights/logo/JQ  JQ523
# 422  https://www.sydneyairport.com.au/flights/logo/VA  VA436
# 423  https://www.sydneyairport.com.au/flights/logo/ZL  ZL783
# 424  https://www.sydneyairport.com.au/flights/logo/QF  QF743
# 425  https://www.sydneyairport.com.au/flights/logo/JQ  JQ609
# 426  https://www.sydneyairport.com.au/flights/logo/QF  QF2178
# 427  https://www.sydneyairport.com.au/flights/logo/JQ  JQ818
# 428  https://www.sydneyairport.com.au/flights/logo/TT  TT384
# 429  https://www.sydneyairport.com.au/flights/logo/ZL  ZL477
# 430  https://www.sydneyairport.com.au/flights/logo/QF  QF1574
# 431  https://www.sydneyairport.com.au/flights/logo/QF  QF548
# 432  https://www.sydneyairport.com.au/flights/logo/VA  VA981
# 433  https://www.sydneyairport.com.au/flights/logo/ZL  ZL681
# 434  https://www.sydneyairport.com.au/flights/logo/QF  QF465
# 435  https://www.sydneyairport.com.au/flights/logo/VA  VA569
# 436  https://www.sydneyairport.com.au/flights/logo/JQ  JQ525
# 437  https://www.sydneyairport.com.au/flights/logo/VA  VA543
# 438  https://www.sydneyairport.com.au/flights/logo/JQ  JQ820
# 439  https://www.sydneyairport.com.au/flights/logo/QF  QF467
# 440  https://www.sydneyairport.com.au/flights/logo/QF  QF1495
# 441  https://www.sydneyairport.com.au/flights/logo/QF  QF583
# 442  https://www.sydneyairport.com.au/flights/logo/JQ  JQ988
# 443  https://www.sydneyairport.com.au/flights/logo/VA  VA888
# 444  https://www.sydneyairport.com.au/flights/logo/TT  TT279
# 445  https://www.sydneyairport.com.au/flights/logo/VA  VA672
# 446  https://www.sydneyairport.com.au/flights/logo/JQ  JQ527
# 447  https://www.sydneyairport.com.au/flights/logo/JQ  JQ611
# 448  https://www.sydneyairport.com.au/flights/logo/JQ  JQ529
# 449  https://www.sydneyairport.com.au/flights/logo/QF  QF497
#
#                                                                                         other_flight_number  \
# 0    EK5002
# 1    AY5915, IB4745
# 2    A31213, AF7232, ET1317, LH9780, LX4172, TK9312, VA5515
# 3    AA7396
# 4    None
# 5    QF8412
# 6    None
# 7    None
# 8    LA7467
# 9    None
# 10   QF270
# 11   AF7876, KL9160
# 12   KC1712, BA4133, OM5601, LH7001, LX9501, AY5841
# 13   AA7375
# 14   None
# 15   None
# 16   AY5001, EK5024, PG4531
# 17   None
# 18   AA7364
# 19   AF3824, AZ3926, EI8050, KL3936, KM2121, ME6634, NZ4250, PK4450, UX3821, VA7086, WY5450, HM5104, MS8084
# 20   VA6551
# 21   NZ9863, LH9327
# 22   9W4028, AY5005
# 23   LH7590, NZ9839
# 24   VA6213
# 25   9W4082, EK5062, MU8470, AY5011, UL3372, PG4535
# 26   None
# 27   TK8020, LH9744, OS8639, LY8401
# 28   None
# 29   None
# ..    ...
# 420  None
# 421  None
# 422  EY6788, VA436
# 423  None
# 424  None
# 425  None
# 426  None
# 427  None
# 428  None
# 429  None
# 430  None
# 431  None
# 432  EY6809
# 433  None
# 434  None
# 435  None
# 436  None
# 437  EY6910
# 438  None
# 439  None
# 440  None
# 441  None
# 442  None
# 443  EY6962
# 444  None
# 445  EY6829, SQ6747
# 446  None
# 447  None
# 448  None
# 449  None
#
#         status scheduled_time estimated_time
# 0    Arrived    05:10          08:31
# 1    Arrived    05:10          05:53
# 2    Arrived    05:55          05:40
# 3    Cancelled  06:05          06:05
# 4    Arrived    06:05          06:01
# 5    Arrived    06:05          06:41
# 6    Arrived    06:10          06:46
# 7    Arrived    06:10          06:06
# 8    Arrived    06:10          06:18
# 9    Arrived    06:10          06:13
# 10   Arrived    06:15          06:51
# 11   Arrived    06:15          06:21
# 12   Arrived    06:15          06:30
# 13   Arrived    06:25          06:32
# 14   Arrived    06:25          06:28
# 15   Arrived    06:25          06:26
# 16   Arrived    06:25          07:26
# 17   Arrived    06:30          07:10
# 18   Arrived    06:30          06:35
# 19   Arrived    06:30          06:23
# 20   Arrived    06:35          07:22
# 21   Arrived    06:55          07:13
# 22   Arrived    06:55          06:53
# 23   Arrived    07:00          06:55
# 24   Arrived    07:00          07:00
# 25   Arrived    07:00          06:38
# 26   Arrived    07:10          07:03
# 27   Arrived    07:20          07:16
# 28   Arrived    07:25          07:24
# 29   Arrived    07:25          07:19
# ..       ...      ...            ...
# 420  Cancelled  18:10          -
# 421  On Time    18:15          -
# 422  On Time    18:15          -
# 423  On Time    18:15          -
# 424  On Time    18:20          -
# 425  On Time    18:25          -
# 426  On Time    18:40          -
# 427  On Time    18:40          -
# 428  On Time    18:50          -
# 429  On Time    18:55          -
# 430  On Time    18:55          -
# 431  On Time    19:00          -
# 432  On Time    19:00          -
# 433  On Time    19:00          -
# 434  On Time    19:00          -
# 435  On Time    19:00          -
# 436  On Time    19:05          -
# 437  On Time    19:10          -
# 438  On Time    19:25          -
# 439  On Time    19:30          -
# 440  On Time    19:35          -
# 441  On Time    19:50          -
# 442  On Time    19:55          -
# 443  On Time    20:00          -
# 444  On Time    20:35          -
# 445  On Time    20:35          -
# 446  On Time    20:40          -
# 447  On Time    21:55          -
# 448  On Time    22:00          -
# 449  On Time    22:05          -
#
# [450 rows x 11 columns]

# %%
flights[flights['status']=='Cancelled']
# Out:
#           type       terminal     journey stopover           airline  \
# 118    arrival       domestic   Melbourne     None           Jetstar
# 165    arrival       domestic       Cooma     None               Rex
# 177    arrival       domestic   Melbourne     None            Qantas
# 181    arrival       domestic    Adelaide     None           Jetstar
# 244    arrival       domestic  Gold Coast     None           Jetstar
# 288    arrival       domestic   Melbourne     None           Jetstar
# 302    arrival       domestic   Melbourne     None           Jetstar
# 343    arrival       domestic   Melbourne     None  Virgin Australia
# 358    arrival       domestic    Brisbane     None            Qantas
# 373    arrival       domestic   Melbourne     None  Virgin Australia
# 428  departure  international        Nadi     None      Fiji Airways
# 548  departure       domestic    Adelaide     None           Jetstar
# 564  departure       domestic       Cooma     None               Rex
# 638  departure       domestic  Gold Coast     None           Jetstar
# 659  departure       domestic      Mudgee     None       Fly Pelican
# 775  departure       domestic   Melbourne     None           Jetstar
# 798  departure       domestic   Melbourne     None           Jetstar
# 813  departure       domestic   Melbourne     None            Qantas
# 819  departure       domestic   Newcastle     None               Rex
# 843  departure       domestic    Brisbane     None  Virgin Australia
#
#          airline_logo flight_number other_flight_number     status  \
# 118  /flights/logo/JQ         JQ500                None  Cancelled
# 165  /flights/logo/ZL         ZL722                None  Cancelled
# 177  /flights/logo/QF         QF422                None  Cancelled
# 181  /flights/logo/JQ         JQ763                None  Cancelled
# 244  /flights/logo/JQ         JQ411                None  Cancelled
# 288  /flights/logo/JQ         JQ514                None  Cancelled
# 302  /flights/logo/JQ         JQ518                None  Cancelled
# 343  /flights/logo/VA         VA869              EY6707  Cancelled
# 358  /flights/logo/QF         QF547                None  Cancelled
# 373  /flights/logo/VA         VA879              EY6949  Cancelled
# 428  /flights/logo/FJ         FJ914               QF345  Cancelled
# 548  /flights/logo/JQ         JQ762                None  Cancelled
# 564  /flights/logo/ZL         ZL721                None  Cancelled
# 638  /flights/logo/JQ         JQ408                None  Cancelled
# 659  /flights/logo/FP         FP247                None  Cancelled
# 775  /flights/logo/JQ         JQ517                None  Cancelled
# 798  /flights/logo/JQ         JQ523                None  Cancelled
# 813  /flights/logo/QF         QF479                None  Cancelled
# 819  /flights/logo/ZL         ZL382                None  Cancelled
# 843  /flights/logo/VA         VA985                None  Cancelled
#
#     scheduled_time estimated_time
# 118          07:25              -
# 165          10:40              -
# 177          11:25              -
# 181          11:30              -
# 244          14:50              -
# 288          16:45              -
# 302          17:30              -
# 343          18:40              -
# 358          19:10              -
# 373          19:55              -
# 428          06:15              -
# 548          06:55              -
# 564          08:00              -
# 638          11:30              -
# 659          12:20              -
# 775          17:25              -
# 798          18:15              -
# 813          18:45          19:20
# 819          18:50              -
# 843          19:30              -

# %%
flights.iloc[1, 1]
# Out:
# 'international'

# %%
flights.sort_values(by=['scheduled_time'], inplace=True)
flights
# Out:
#           type       terminal        journey       stopover  \
# 0      arrival  international         London  Via Singapore
# 1      arrival  international         London  Via Singapore
# 2      arrival  international      Singapore           None
# 476  departure       domestic      Melbourne           None
# 477  departure       domestic      Melbourne           None
# 478  departure       domestic         Cairns           None
# 479  departure       domestic         Hobart           None
# 367  departure  international          Dubai           None
# 366  departure  international     Queenstown           None
# 480  departure       domestic       Brisbane           None
# 112    arrival       domestic          Perth           None
# 4      arrival  international        Jakarta           None
# 5      arrival  international          Dubai           None
# 110    arrival       domestic         Darwin           None
# 111    arrival       domestic          Perth           None
# 3      arrival  international  San Francisco           None
# 481  departure       domestic      Melbourne           None
# 6      arrival  international          Delhi           None
# 482  departure       domestic     Gold Coast           None
# 9      arrival  international         Manila           None
# 7      arrival  international       Denpasar           None
# 8      arrival  international          Tokyo           None
# 12     arrival  international      Hong Kong           None
# 11     arrival  international          Seoul           None
# 10     arrival  international       Denpasar           None
# 368  departure  international           Nadi           None
# 113    arrival       domestic          Perth           None
# 16     arrival  international        Bangkok           None
# 15     arrival  international       Denpasar           None
# 14     arrival  international       Shenzhen           None
# ..         ...            ...            ...            ...
# 466  departure  international          Tokyo           None
# 352    arrival       domestic     Gold Coast           None
# 353    arrival       domestic      Melbourne           None
# 467  departure  international          Dubai           None
# 468  departure  international           Doha           None
# 470  departure  international      Singapore   Via Canberra
# 469  departure  international      Hong Kong           None
# 471  departure  international            APW           None
# 355    arrival       domestic      Melbourne           None
# 354    arrival       domestic         Broome           None
# 356    arrival       domestic         Cairns           None
# 472  departure  international       Honolulu           None
# 357    arrival       domestic       Brisbane           None
# 358    arrival       domestic         Hobart           None
# 473  departure  international      Hong Kong           None
# 361    arrival       domestic      Melbourne           None
# 359    arrival       domestic            MCY           None
# 360    arrival       domestic         Avalon           None
# 703  departure       domestic         Avalon           None
# 107    arrival  international           Nadi           None
# 704  departure       domestic      Melbourne           None
# 108    arrival  international          Dubai           None
# 705  departure       domestic      Melbourne           None
# 362    arrival       domestic       Brisbane           None
# 109    arrival  international     Queenstown           None
# 475  departure  international   Kuala Lumpur           None
# 474  departure  international         Taipei           None
# 363    arrival       domestic       Brisbane           None
# 364    arrival       domestic          Perth           None
# 365    arrival       domestic          Perth           None
#
#                       airline      airline_logo flight_number  \
# 0                      Qantas  /flights/logo/QF           QF2
# 1            British Airways   /flights/logo/BA          BA15
# 2         Singapore Airlines   /flights/logo/SQ         SQ221
# 476          Virgin Australia  /flights/logo/VA         VA800
# 477                    Qantas  /flights/logo/QF         QF401
# 478                   Jetstar  /flights/logo/JQ         JQ952
# 479                   Jetstar  /flights/logo/JQ         JQ719
# 367                 Emirates   /flights/logo/EK         EK415
# 366          Air New Zealand   /flights/logo/NZ         NZ834
# 480                   Jetstar  /flights/logo/JQ         JQ810
# 112          Virgin Australia  /flights/logo/VA         VA572
# 4                      Qantas  /flights/logo/QF          QF42
# 5                   Emirates   /flights/logo/EK         EK412
# 110                   Jetstar  /flights/logo/JQ         JQ671
# 111                    Qantas  /flights/logo/QF         QF568
# 3                      Qantas  /flights/logo/QF          QF74
# 481                   Jetstar  /flights/logo/JQ         JQ501
# 6                   Air India  /flights/logo/AI         AI302
# 482                   Jetstar  /flights/logo/JQ         JQ400
# 9                      Qantas  /flights/logo/QF          QF20
# 7            Virgin Australia  /flights/logo/VA          VA36
# 8              Japan Airlines  /flights/logo/JL         JL771
# 12     Cathay Pacific Airways  /flights/logo/CX         CX111
# 11                 Korean Air  /flights/logo/KE         KE121
# 10                    Jetstar  /flights/logo/JQ          JQ38
# 368              Fiji Airways  /flights/logo/FJ         FJ914
# 113                   Jetstar  /flights/logo/JQ         JQ989
# 16                     Qantas  /flights/logo/QF          QF24
# 15                     Qantas  /flights/logo/QF          QF44
# 14   China Southern Airlines   /flights/logo/CZ        CZ3071
# ..                        ...               ...           ...
# 466        All Nippon Airways  /flights/logo/NH         NH880
# 352                   Jetstar  /flights/logo/JQ         JQ419
# 353                   Jetstar  /flights/logo/JQ         JQ530
# 467                 Emirates   /flights/logo/EK         EK413
# 468             Qatar Airways  /flights/logo/QR         QR909
# 470       Singapore Airlines   /flights/logo/SQ         SQ288
# 469                    Qantas  /flights/logo/QF         QF117
# 471             Samoa Airways  /flights/logo/OL         OL856
# 355          Virgin Australia  /flights/logo/VA         VA891
# 354                    Qantas  /flights/logo/QF        QF1043
# 356                   Jetstar  /flights/logo/JQ         JQ959
# 472         Hawaiian Airlines  /flights/logo/HA         HA452
# 357          Virgin Australia  /flights/logo/VA         VA992
# 358                   Jetstar  /flights/logo/JQ         JQ724
# 473    Cathay Pacific Airways  /flights/logo/CX         CX138
# 361                    Qantas  /flights/logo/QF         QF492
# 359                   Jetstar  /flights/logo/JQ         JQ789
# 360                   Jetstar  /flights/logo/JQ         JQ610
# 703                   Jetstar  /flights/logo/JQ         JQ611
# 107              Fiji Airways  /flights/logo/FJ         FJ915
# 704                   Jetstar  /flights/logo/JQ         JQ529
# 108                 Emirates   /flights/logo/EK         EK414
# 705                    Qantas  /flights/logo/QF         QF497
# 362                    Qantas  /flights/logo/QF         QF557
# 109          Air New Zealand   /flights/logo/NZ         NZ835
# 475         Malaysia Airlines  /flights/logo/MH         MH140
# 474          China Airlines    /flights/logo/CI          CI52
# 363                   Jetstar  /flights/logo/JQ         JQ819
# 364                    Qantas  /flights/logo/QF         QF566
# 365          Virgin Australia  /flights/logo/VA         VA564
#
#                                    other_flight_number     status  \
# 0                                               EK5002    Arrived
# 1                                       AY5915, IB4745    Arrived
# 2    A31213, AF7232, ET1317, LH9780, LX4172, TK9312...    Arrived
# 476                                     EY6823, HU8846   Departed
# 477                                               None   Departed
# 478                                               None   Departed
# 479                                               None   Departed
# 367                                             QF8415   Departed
# 366                                               None   Departed
# 480                                               None   Departed
# 112                                     DL7259, EY6725    Arrived
# 4                                                 None    Arrived
# 5                                               QF8412    Arrived
# 110                                               None    Arrived
# 111                                               None    Arrived
# 3                                               AA7396  Cancelled
# 481                                               None   Departed
# 6                                                 None    Arrived
# 482                                               None   Departed
# 9                                                 None    Arrived
# 7                                                 None    Arrived
# 8                                               LA7467    Arrived
# 12      KC1712, BA4133, OM5601, LH7001, LX9501, AY5841    Arrived
# 11                                      AF7876, KL9160    Arrived
# 10                                               QF270    Arrived
# 368                                              QF345   Departed
# 113                                               None    Arrived
# 16                              AY5001, EK5024, PG4531    Arrived
# 15                                                None    Arrived
# 14                                                None    Arrived
# ..                                                 ...        ...
# 466                                             NZ4158    On Time
# 352                                               None    On Time
# 353                                               None    On Time
# 467                                             QF8413    On Time
# 468                                             S74806    On Time
# 470                     LH9760, LO4019, LX4184, VA5435    On Time
# 469                                     9W4001, AY5024    On Time
# 471                                               None    On Time
# 355                                     EY6964, HU8639    On Time
# 354                                               None    On Time
# 356                                               None    On Time
# 472                                             VA5100    On Time
# 357                                     EY6567, HU8104    On Time
# 358                                               None    On Time
# 473                             BA4134, OM5602, AY5112    On Time
# 361                                               None    On Time
# 359                                               None    On Time
# 360                                               None    On Time
# 703                                               None    On Time
# 107                                              QF346    On Time
# 704                                               None    On Time
# 108                                             QF8414    On Time
# 705                                               None    On Time
# 362                                               None    On Time
# 109                                               None  Cancelled
# 475                                     UL2340, KL4118    On Time
# 474                              QF389, KL4990, AF4161    On Time
# 363                                               None    On Time
# 364                                               None    On Time
# 365                                             EY6731    On Time
#
#     scheduled_time estimated_time
# 0            05:10          08:31
# 1            05:10          05:53
# 2            05:55          05:40
# 476          06:00          06:00
# 477          06:00              -
# 478          06:00              -
# 479          06:00              -
# 367          06:00              -
# 366          06:00          06:04
# 480          06:05              -
# 112          06:05          06:04
# 4            06:05          06:01
# 5            06:05          06:41
# 110          06:05          06:11
# 111          06:05          06:08
# 3            06:05          06:05
# 481          06:05              -
# 6            06:10          06:46
# 482          06:10              -
# 9            06:10          06:13
# 7            06:10          06:06
# 8            06:10          06:18
# 12           06:15          06:30
# 11           06:15          06:21
# 10           06:15          06:51
# 368          06:15              -
# 113          06:20          06:16
# 16           06:25          07:26
# 15           06:25          06:26
# 14           06:25          06:28
# ..             ...            ...
# 466          20:55              -
# 352          21:00              -
# 353          21:05              -
# 467          21:10              -
# 468          21:15              -
# 470          21:20              -
# 469          21:20              -
# 471          21:25              -
# 355          21:25              -
# 354          21:25              -
# 356          21:40              -
# 472          21:40              -
# 357          21:40              -
# 358          21:50              -
# 473          21:55              -
# 361          21:55              -
# 359          21:55              -
# 360          21:55              -
# 703          21:55              -
# 107          21:55              -
# 704          22:00              -
# 108          22:05          21:34
# 705          22:05              -
# 362          22:10              -
# 109          22:10              -
# 475          22:10              -
# 474          22:10              -
# 363          22:15              -
# 364          22:30              -
# 365          22:40              -
#
# [706 rows x 11 columns]

# %%
from datetime import datetime
timestr = flights.iloc[1, -1]
timeobj = datetime.strptime(flights.iloc[1, -1], "%H:%M")

type(timestr)
print(timestr)

type(timeobj)
print(timeobj)
# Out:
# 05:53
# 1900-01-01 05:53:00

# %%
print(flights.head(1).to_html(classes=['flights'], escape=False ,formatters=dict(airline_logo=path_to_image_html)))
# Out:
# <table border="1" class="dataframe flights">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>terminal</th>
#       <th>journey</th>
#       <th>stopover</th>
#       <th>airline</th>
#       <th>airline_logo</th>
#       <th>flight_number</th>
#       <th>other_flight_number</th>
#       <th>status</th>
#       <th>scheduled_time</th>
#       <th>estimated_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>arrival</td>
#       <td>international</td>
#       <td>London</td>
#       <td>Via Singapore</td>
#       <td>Qantas</td>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/QF" width="60" ></td>
#       <td>QF2</td>
#       <td>EK5002</td>
#       <td>Arrived</td>
#       <td>05:10</td>
#       <td>08:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
from IPython.core.display import HTML
def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

pd.set_option('display.max_colwidth', -1)

HTML(flights.to_html(escape=False ,formatters=dict(airline_logo=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>terminal</th>
#       <th>journey</th>
#       <th>stopover</th>
#       <th>airline</th>
#       <th>airline_logo</th>
#       <th>flight_number</th>
#       <th>other_flight_number</th>
#       <th>status</th>
#       <th>scheduled_time</th>
#       <th>estimated_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>arrival</td>
#       <td>international</td>
#       <td>London</td>
#       <td>Via Singapore</td>
#       <td>Qantas</td>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/QF" width="60" ></td>
#       <td>QF2</td>
#       <td>EK5002</td>
#       <td>Arrived</td>
#       <td>05:10</td>
#       <td>08:31</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>arrival</td>
#       <td>international</td>
#       <td>London</td>
#       <td>Via Singapore</td>
#       <td>British Airways</td>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/BA" width="60" ></td>
#       <td>BA15</td>
#       <td>AY5915, IB4745</td>
#       <td>Arrived</td>
#       <td>05:10</td>
#       <td>05:53</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>arrival</td>
#       <td>international</td>
#       <td>Singapore</td>
#       <td>None</td>
#       <td>Singapore Airlines</td>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/SQ" width="60" ></td>
#       <td>SQ221</td>
#       <td>A31213, AF7232, ET1317, LH9780, LX4172, TK9312, VA5515</td>
#       <td>Arrived</td>
#       <td>05:55</td>
#       <td>05:40</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>arrival</td>
#       <td>international</td>
#       <td>San Francisco</td>
#       <td>None</td>
#       <td>Qantas</td>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/QF" width="60" ></td>
#       <td>QF74</td>
#       <td>AA7396</td>
#       <td>Cancelled</td>
#       <td>06:05</td>
#       <td>06:05</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>arrival</td>
#       <td>international</td>
#       <td>Jakarta</td>
#       <td>None</td>
#       <td>Qantas</td>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo
td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>arrival</td>
#       <td>international</td>
#       <td>Abu Dhabi</td>
#       <td>None</td>
#       <td>Etihad Airways</td>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/EY" width="60" ></td>
#       <td>EY450</td>
#       <td>AF3824, AZ3926, EI8050, KL3936, KM2121, ME6634, NZ4250, PK4450, UX3821, VA7086, WY5450, HM5104, MS8084</td>
#       <td>Arrived</td>
#       <td>06:30</td>
#       <td>06:23</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>arrival</td>
#       <td>international</td>
#       <td>Los Angeles</td>
#       <td>None</td>
#       <td>Delta Air Lines</td>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/DL" width="60" ></td>
#       <td>DL41</td>
#       <t

# %%
print("\"")
# Out:
# "

# %%
print('<img src=\"'+ "hello" + '\" width=\"60\" >')
# Out:
# <img src="hello" width="60" >

# %%
def flightscraper():

    from datetime import datetime
    from selenium import webdriver
    from selenium.webdriver.chrome.options import Options
    from bs4 import BeautifulSoup
    import numpy as np
    import pandas as pd

    # Initialise instance of Chrome driver
    chrome_options = Options()  
    chrome_options.add_argument("--headless")
    driver = webdriver.Chrome(options=chrome_options)

    # Define query strings for url
    today = datetime.today().strftime('%Y-%m-%d')
    flight_types  = ["arrival", "departure"]
    terminal_types = ["international", "domestic"]

    # Initialise empty lists
    journies = []
    types = []
    terminals = []
    stopovers = []
    airlines = []
    airline_logos = []
    flight_numbers = []
    other_flight_numbers = []
    statuses = []
    scheduled_times = []
    estimated_times = []

    # Loop through each combination of (domestic/international) x (arrival/departure)
    for flight_type in flight_types:
        for terminal_type in terminal_types:
            url = "https://www.sydneyairport.com.au/flights/?query=&flightType=" + flight_type + "&terminalType=" + terminal_type + "&date=" + today + "&sortColumn=scheduled_time&ascending=true&showAll=true"
            driver.get(url)
            
            html_soup = BeautifulSoup(driver.page_source, "html.parser")
            flight_containers = html_soup.find_all("div", attrs={"class": "flight-card"})[2:]
            
            # Loop through all containers (one for each flight) to extract and store info
            for container in flight_containers:
                # Arrival / departure
                types.append(flight_type)
                
                # International / domestic
                terminals.append(terminal_type)
                
                # Origin / Destinations
                journies.append(container.find("div", attrs={"class": "destination-name"}).text)

                # Stopovers (if any)
                if container.find("div", attrs={"class": "city-via"}) is not None:
                    stopovers.append(container.find("div", attrs={"class": "city-via"}).text)
                else:
                    stopovers.append(None)

                # Airlines
                airlines.append(container.find("span", attrs={"class": "with-image"}).text)

                # Airline logos
                airline_logos.append("https://www.sydneyairport.com.au" + container.img['src'])

                # Flight numbers
                flight_numbers.append(container.find("div", attrs={"class": "heading-medium"}).text)

                # Alternative flight numbers (if any)
                if container.find("div", attrs={"class": "body-xsmall"}) is not None:
                    other_flight_numbers.append(container.find("div", attrs={"class": "body-xsmall"}).text)
                else:
                    other_flight_numbers.append(None)

                # Statuses
                statuses.append(container.find("div", attrs={"class": "status"}).text)

                # Scheduled times
                scheduled_times.append(container.find("div", attrs={"class": "large-scheduled-time"}).text)

                # Estimated times
                estimated_times.append(container.find("div", attrs={"class": "estimated-time"}).text)
        
        
    # Create dataframe from lists
    flights = pd.DataFrame({'journey': journies,
                            'type': types,
                            'terminal': terminals,
                            'stopover': stopovers,
                            'airline': airlines,
                            'airline_logo': airline_logos,
                            'flight_number': flight_numbers,
                            'other_flight_number': other_flight_numbers,
                            'status': statuses,
                            'scheduled_time': scheduled_times,
                            'estimated_time': estimated_times})
    # Reorder columns
    flights = flights[['airline_logo', 'type', 'terminal', 'journey', 'stopover', 'airline', 'flight_number', 'other_flight_number', 'status', 'scheduled_time', 'estimated_time']]
    
    # Order flights by scheduled time
    flights.sort_values(by=['scheduled_time'], inplace=True)
    flights.reset_index(drop=True, inplace=True)
    
    return flights

# %%
HTML(flightscraper().to_html(classes="flights", escape=False, formatters=dict(airline_logo=path_to_image_html)))
# Out:
# <table border="1" class="dataframe flights">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>airline_logo</th>
#       <th>type</th>
#       <th>terminal</th>
#       <th>journey</th>
#       <th>stopover</th>
#       <th>airline</th>
#       <th>flight_number</th>
#       <th>other_flight_number</th>
#       <th>status</th>
#       <th>scheduled_time</th>
#       <th>estimated_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/QF" width="60" ></td>
#       <td>arrival</td>
#       <td>international</td>
#       <td>London</td>
#       <td>Via Singapore</td>
#       <td>Qantas</td>
#       <td>QF2</td>
#       <td>EK5002</td>
#       <td>Arrived</td>
#       <td>05:10</td>
#       <td>08:31</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/BA" width="60" ></td>
#       <td>arrival</td>
#       <td>international</td>
#       <td>London</td>
#       <td>Via Singapore</td>
#       <td>British Airways</td>
#       <td>BA15</td>
#       <td>AY5915, IB4745</td>
#       <td>Arrived</td>
#       <td>05:10</td>
#       <td>05:53</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/SQ" width="60" ></td>
#       <td>arrival</td>
#       <td>international</td>
#       <td>Singapore</td>
#       <td>None</td>
#       <td>Singapore Airlines</td>
#       <td>SQ221</td>
#       <td>A31213, AF7232, ET1317, LH9780, LX4172, TK9312, VA5515</td>
#       <td>Arrived</td>
#       <td>05:55</td>
#       <td>05:40</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/VA" width="60" ></td>
#       <td>departure</td>
#       <td>domestic</td>
#       <td>Melbourne</td>
#       <td>None</td>
#       <td>Virgin Australia</td>
#       <td>VA800</td>
#       <td>EY6823, HU8846</td>
#       <td>Departed</td>
#       <td>06:00</td>
#       <td>06:00</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/QF" width="60" ></td>
#       <td>departure</td>
#       <td>domestic</td>
#       <td>Melbourne</td>
#       <td>None</td>
#       <td>Qantas</td>
#       <td>QF401</td>
#       <td>None</td>
#       <td>Departed</td>
#       <td>06:00</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/JQ" width="60" ></td>
#       <td>departure</td>
#       <td>domestic</td>
#       <td>Cairns</td>
#       <td>None</td>
#       <td>Jetstar</td>
#       <td>JQ952</td>
#       <td>None</td>
#       <td>Departed</td>
#       <td>06:00</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/JQ" width="60" ></td>
#       <td>departure</td>
#       <td>domestic</td>
#       <td>Hobart</td>
#       <td>None</td>
#       <td>Jetstar</td>
#       <td>JQ719</td>
#       <td>None</td>
#       <td>Departed</td>
#       <td>06:00</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/NZ" width="60" ></td>
#       <td>departure</td>
#       <td>international</td>
#       <td>Queenstown</td>
#       <td>None</td>
#       <td>Air New Zealand</td>
#       <td>NZ834</td>
#       <td>None</td>
#       <td>Departed</td>
#       <td>06:00</td>
#       <td>06:04</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo/EK" width="60" ></td>
#       <td>departure</td>
#       <td>international</td>
#       <td>Dubai</td>
#       <td>None</td>
#       <td>Emirates</td>
#       <td>EK415</td>
#       <td>QF8415</td>
#       <td>Departed</td>
#       <td>06:00</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="https://www.sydneyairport.com.au/flights/logo